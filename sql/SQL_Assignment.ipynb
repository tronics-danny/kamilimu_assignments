# %% [markdown]
# **SQL ASSIGNMENT**
#
# **Daniel Maithya**

# %%
#Importing the sqlite3 module and the panda library
import sqlite3
import pandas as pd

# Load datasets
athletes = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-27/athlete_events.csv")
regions = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-27/noc_regions.csv")
sales = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
sales = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')


# Connect to SQLite in-memory DB
conn = sqlite3.connect(":memory:")

# Write DataFrames to SQL tables
athletes.to_sql("athletes_table", conn, index=False, if_exists="replace")
regions.to_sql("regions_table", conn, index=False, if_exists="replace")
sales.to_sql("sales_table", conn, index=False, if_exists="replace")
# Out:
# 4622

# %% [markdown]
# **Section 1**

# %% [markdown]
# The athletes dataset:

# %% [markdown]
# 1. Top 5 total number of medals won by each country.

# %% [markdown]
# Visualizing the data held in the athletes table

# %%
#Here I am viewing the date in the athletes table
pd.read_sql(
    """
    SELECT *
    FROM athletes_table
    """,
    conn
)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# Visualizing data held in the regions table

# %%
#Here I am viewing the data held in the regions table
pd.read_sql(
    """
    SELECT *
    FROM regions_table
    """,
    conn
)
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                  None
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                  None
# 3    ALG      Algeria                  None
# 4    AND      Andorra                  None
# ..   ...          ...                   ...
# 225  YEM        Yemen                  None
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                  None
# 229  ZIM     Zimbabwe                  None
#
# [230 rows x 3 columns]

# %% [markdown]
# Grouping by country's that won gold and listing the top 5

# %%
pd.read_sql(
    """
    SELECT r.region AS country, COUNT(a.medal) AS total_medals
    FROM athletes_table a
    JOIN regions_table r ON a.NOC = r.NOC
    WHERE a.Medal = 'Gold'
    GROUP BY country
    ORDER BY total_medals DESC
    LIMIT 5;
    """,
    conn
)
# Out:
#    country  total_medals
# 0      USA          2638
# 1   Russia          1599
# 2  Germany          1301
# 3       UK           678
# 4    Italy           575

# %% [markdown]
# 2. Average age of athletes who won a Gold medal.

# %%
pd.read_sql(
    """
    SELECT AVG(Age) AS avg_age_gold_medalists
    FROM athletes_table
    WHERE medal = 'Gold'
    """,
    conn
)
# Out:
#    avg_age_gold_medalists
# 0               25.901013

# %% [markdown]
# 3. Distinct events in each sport

# %%
pd.read_sql(
    """
    SELECT Sport, COUNT(DISTINCT Event) AS no_of_events
    FROM athletes_table
    GROUP BY Sport
    ORDER BY no_of_events DESC
    """,
    conn
)
# Out:
#             Sport  no_of_events
# 0        Shooting            83
# 1       Athletics            83
# 2        Swimming            55
# 3         Cycling            44
# 4         Sailing            38
# ..            ...           ...
# 61        Cricket             1
# 62  Basque Pelota             1
# 63       Baseball             1
# 64       Alpinism             1
# 65    Aeronautics             1
#
# [66 rows x 2 columns]

# %% [markdown]
# 4. All athletes from the United States (NOC = 'USA').

# %%
pd.read_sql(
    """
    SELECT *
    FROM athletes_table
    WHERE NOC = 'USA'
    """,
    conn
)
# Out:
#            ID                        Name Sex   Age  Height  Weight  \
# 0           6             Per Knut Aaland   M  31.0   188.0    75.0
# 1           6             Per Knut Aaland   M  31.0   188.0    75.0
# 2           6             Per Knut Aaland   M  31.0   188.0    75.0
# 3           6             Per Knut Aaland   M  31.0   188.0    75.0
# 4           6             Per Knut Aaland   M  33.0   188.0    75.0
# ...       ...                         ...  ..   ...     ...     ...
# 18848  135458                    Rami Zur   M  27.0   175.0    77.0
# 18849  135458                    Rami Zur   M  31.0   175.0    77.0
# 18850  135458                    Rami Zur   M  31.0   175.0    77.0
# 18851  135543  Victor Andrew "Vic" Zwolak   M  25.0   175.0    64.0
# 18852  135566  James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
#                 Team  NOC        Games  Year  Season         City  \
# 0      United States  USA  1992 Winter  1992  Winter  Albertville
# ...

# %% [markdown]
# 5. Medals were awarded each year.

# %%
pd.read_sql(
    """
    SELECT Year, COUNT(Medal) AS no_of_medals
    FROM athletes_table
    GROUP BY Year
    ORDER BY Year
    """,
    conn
)
# Out:
#     Year  no_of_medals
# 0   1896           143
# 1   1900           604
# 2   1904           486
# 3   1906           458
# 4   1908           831
# 5   1912           941
# 6   1920          1308
# 7   1924           962
# 8   1928           823
# 9   1932           739
# 10  1936          1025
# 11  1948           987
# 12  1952          1033
# 13  1956          1043
# 14  1960          1058
# 15  1964          1215
# 16  1968          1256
# 17  1972          1414
# 18  1976          1531
# 19  1980          1602
# 20  1984          1698
# 21  1988          1845
# 22  1992          2030
# 23  1994           331
# 24  1996          1842
# 25  1998           440
# 26  2000          2004
# 27  2002           478
# 28  2004          2001
# 29  2006           526
# 30  2008          2048
# 31  2010           520
# 32  2012          1941
# 33  2014           597
# 34  2016          2023

# %% [markdown]
# 6. All athlete records where height or weight is missing.

# %%
pd.read_sql(
    """
    SELECT *
    FROM athletes_table
    WHERE Height IS NULL OR Weight IS NULL
    """,
    conn
)
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 0           3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 1           4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 2           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 3           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 4          10      Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# ...       ...                                 ...  ..   ...     ...     ...
# 64258  135539               Marius Edmund Zwiller   M  18.0     NaN     NaN
# 64259  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 64260  135542                      Werner Zwingli   M  29.0     NaN     NaN
# 64261  135552     Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 64262  135561                       Frantiek Zyka   M  26.0     NaN     NaN
#
# ...

# %% [markdown]
# 7. Replacing the missing height with the average athlete height.

# %%
pd.read_sql(
    """
    SELECT *, COALESCE(height, (
        SELECT AVG(height)
        FROM athletes_table
        WHERE height IS NOT NULL
    )) AS new_height
    FROM athletes_table;
    """,
    conn
)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# The sales dataset: where necessary, use the key word CAST to remove the $ sign from the item_price
#
#   Visualizing data held in the sales dataset

# %%
pd.read_sql(
    """
    SELECT *
    FROM sales_table
    """,
    conn
)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                  None     $2.39
# ...

# %% [markdown]
# 8. Total sales value per item.

# %%
pd.read_sql(
    """
    SELECT item_name, SUM(item_price) AS total_sales_value
    FROM sales_table
    GROUP BY item_name
    """,
    conn
)
# Out:
#                                 item_name  total_sales_value
# 0                       6 Pack Soft Drink                0.0
# 1                           Barbacoa Bowl                0.0
# 2                        Barbacoa Burrito                0.0
# 3                   Barbacoa Crispy Tacos                0.0
# 4                     Barbacoa Salad Bowl                0.0
# 5                     Barbacoa Soft Tacos                0.0
# 6                           Bottled Water                0.0
# 7                                    Bowl                0.0
# 8                                 Burrito                0.0
# 9                             Canned Soda                0.0
# 10                      Canned Soft Drink                0.0
# 11                          Carnitas Bowl                0.0
# 12                       Carnitas Burrito                0.0
# 13                  Carnitas Crispy Tacos                0.0
# ...

# %% [markdown]
# 9. Top 5 records with the highest item_price.

# %%
pd.read_sql (
    """
    SELECT *
    FROM sales_table
    ORDER BY item_price DESC
    LIMIT 5
    """,
    conn
)
# Out:
#    order_id  quantity            item_name  \
# 0       250         1     Steak Salad Bowl
# 1       576         1  Barbacoa Salad Bowl
# 2       576         1  Barbacoa Salad Bowl
# 3       738         1  Barbacoa Salad Bowl
# 4       756         1  Carnitas Salad Bowl
#
#                                   choice_description item_price
# 0                      [Fresh Tomato Salsa, Lettuce]     $9.39
# 1                         [Roasted Chili Corn Salsa]     $9.39
# 2                         [Roasted Chili Corn Salsa]     $9.39
# 3  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 4   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $9.39

# %% [markdown]
# 10. Number of unique customer orders available. (Assume each order_id is a customer.)

# %%
pd.read_sql(
    """
    SELECT COUNT(DISTINCT order_id) AS unique_orders
    FROM sales_table
    """,
    conn
)
# Out:
#    unique_orders
# 0           1834

# %% [markdown]
# **Section 2**

# %% [markdown]
# Write one query for this section.
#
# Find countries with high-performing athletes in the Olympics. Use at least JOIN, NESTED QUERY, CASE, and optionally WITH.
#
# For each country:
#
# Count the number of athletes who won at least one medal.
# Determine the average age of those medalists.
# Create a new column called performance:
# - 'High' if average age is below 25
# - 'Medium' if between 25 and 30
# - 'Low' if above 30

# %%
pd.read_sql(
    """
    WITH medalists AS (
        SELECT DISTINCT a.ID, a.name, a.age, r.region AS country
        FROM athletes_table a
        JOIN regions_table r ON a.NOC = r.NOC
        WHERE a.medal IS NOT NULL
    ),
    country_stats AS (
        SELECT
            country,
            COUNT(*) AS num_medalists,
            AVG(age) AS avg_age
        FROM medalists
        WHERE age IS NOT NULL
        GROUP BY country
    )
    SELECT
        country,
        num_medalists,
        ROUND(avg_age, 2) AS avg_age,
        CASE
            WHEN avg_age < 25 THEN 'High'
            WHEN avg_age BETWEEN 25 AND 30 THEN 'Medium'
            ELSE 'Low'
        END AS performance
    FROM country_stats
    ORDER BY num_medalists DESC
    LIMIT 20;
    """,
    conn
)
# Out:
#            country  num_medalists  avg_age performance
# 0              USA           4618    25.09      Medium
# 1           Russia           3398    25.40      Medium
# 2          Germany           3233    25.54      Medium
# 3               UK           1778    27.87      Medium
# 4           France           1446    27.61      Medium
# 5            Italy           1422    26.88      Medium
# 6           Sweden           1380    27.97      Medium
# 7           Canada           1231    26.00      Medium
# 8        Australia           1153    25.29      Medium
# 9          Hungary            990    26.42      Medium
# 10     Netherlands            928    26.40      Medium
# 11          Norway            870    27.69      Medium
# 12           China            849    23.36        High
# 13           Japan            783    24.44        High
# 14         Finland            771    27.36      Medium
# 15  Czech Republic            597    26.08      Medium
# ...
